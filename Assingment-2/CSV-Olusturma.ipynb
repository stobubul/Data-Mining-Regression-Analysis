# %%
import pandas as pd
import numpy as np

# %%
data = {
    'Ogrenci_ID': list(range(1, 38)),
    'Ders_Adi': ['BİL 2009 - Çizge Kuramı'] * 37,
    'Haftalik_Ders_Saati': [4] * 37, 
    'AKTS': [6] * 37,              
    'Tekrar_Sayisi': [1, 1, 1, 1, 3, 1, 1, 1, 1, 1, 0, 1, 2, 2, 1, 1, 0, 2, 0, 0, 1, 1, 1, 1, 3, 2, 0, 2, 1, 1, 0, 1, 1, 1, 0, 1, 1],
    'Ders_Disi_Calısma_Saati': [1.5, 1.0, 0.0, 1.2, 3.4, 2.0, 0.0, 1.5, 1.5, 1.5, 0.5, 1.0, 2.0, 1.0, 1.0, 1.1, 0.5, 2.0, 0.5, 0.5, 1.0, 2.0, 1.5, 1.0, 3.5, 3.0, 0.0, 3.0, 1.5, 2.5, 0.5, 1.0, 0.5, 1.5, 0.5, 1.0, 2.5],
    'Arasinav_Notu': [88.0, 80.0, 47.0, 84.0, 100.0, 89.0, 56.0, 88.0, 90.0, 82.0, 73.0, 70.0, 99.0, 75.0, 75.0, 80.0, 31.0, 99.0, 46.0, 76.0, 28.0, 93.0, 89.0, 35.0, 97.0, 98.0, 42.0, 92.0, 82.0, 88.0, 76.0, 99.0, 80.0, 90.0, 59.0, 80.0, 91.0]
}

# %%
df = pd.DataFrame(data)

# %% [markdown]
# ## **DataFrame'i CSV dosyası olarak kaydetme**

# %%
df.to_csv('ogrenci_basari_veriseti.csv', index = False, encoding = 'utf-8')

# %%
print("DataFrame başarıyla 'ogrenci_basari_veriseti.csv' olarak kaydedildi.")
print("index=False, satır numaralarının (index) dosyaya yazılmasını engeller.")
# Out:
# DataFrame başarıyla 'ogrenci_basari_veriseti.csv' olarak kaydedildi.
# index=False, satır numaralarının (index) dosyaya yazılmasını engeller.
